# %%
import pandas as pd
import urllib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
merged = pd.read_parquet("/scratch/venia/web2wiki/data/en_shares_merged2.parquet")
df = pd.read_csv("/scratch/venia/web2wiki/data/web_content/iterative_coding_sample/cleaner_data.csv")

# %%
in_links = pd.read_parquet("/scratch/venia/web2wiki/data/enwiki_inlinks_2022-01.parquet")
in_links = in_links.rename(columns={"target_qid":"qid"})
in_links = in_links.rename(columns={"count":"in_links"})
#.read.csv("/dlabdata1/orphans/data/wiki_graphs/enwiki_links_2022-01.csv",header =True)

# %%
reddit_counts = pd.read_parquet("/scratch/venia/web2wiki/data/reddit_wikipedia_counts.parquet/")
reddit_counts = reddit_counts.rename(columns={"title_final":"title"})
reddit_counts = reddit_counts.rename(columns={"count":"reddit_count"})

# %%
t = merged.merge(reddit_counts,on="title", how = "left")
t = in_links.merge(t, on = "qid", how = "right")

# %%
df = df[df["wiki_links"].str.contains("en.wikipedia.org")]

# %%
def normalise_title(title):
    """ Replace _ with space, remove anchor, capitalize """
    title = title.split("/")[-1]
    title = title.split("#")[0]
    title = urllib.parse.unquote(title)
    title = title.strip()
    if len(title) > 0:
        title = title[0].upper() + title[1:]
    n_title = title.replace("_", " ")
    # if '#' in n_title:
    #     n_title = n_title.split('#')[0]
    return n_title

# %%
df["title"] = df["wiki_links"].apply(lambda x: normalise_title(x))

# %%
df = df[df["title"]!= ""]
df = df[df["title"]!= "Main Page"]

# %%
df2 = df.drop_duplicates(subset = ["domain","title"])

# %%
df2 = df2.merge(merged, on = "title")

# %%
order_counts = df2.groupby(["order", "topic_leaf"])["url"].count().reset_index()
order_counts = order_counts.sort_values(by = "url",ascending=False)
order_counts["order_count"] = order_counts.groupby("order")["url"].transform("sum")
order_counts["p"] = order_counts["url"] / order_counts["order_count"] 
mean = order_counts.groupby("topic_leaf")["p"].mean().reset_index()
mean = mean.rename(columns={"p":"mean"})
std = order_counts.groupby("topic_leaf")["p"].std().reset_index()
std= std.rename(columns={"p":"std"})

order_counts=order_counts.merge(mean, on = "topic_leaf")
order_counts=order_counts.merge(std, on = "topic_leaf")

top_20 = order_counts.groupby("topic_leaf")["url"].sum().sort_values(ascending=False).head(20).index
order_counts2 = order_counts[order_counts["topic_leaf"].isin(top_20)]

order_counts2["z"] = order_counts2.apply(lambda x: (x["p"] - x["mean"]) / x["std"],axis=1)

order_counts2 = order_counts2.sort_values(by = "z",ascending=False)
order_counts2.groupby("order").head(10).sort_values(by = "order")
# Out:
# /tmp/ipykernel_857184/3936106931.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order_counts2["z"] = order_counts2.apply(lambda x: (x["p"] - x["mean"]) / x["std"],axis=1)
#     order               topic_leaf    url  order_count         p      mean  \
# 22      0                  Biology    891        11743  0.075875  0.050686
# 37      0               Technology    391        11743  0.033296  0.032364
# 55      0               South_Asia    197        11743  0.016776  0.014898
# 58      0          Southern_Europe    200        11743  0.017031  0.016014
# 40      0           Western_Europe    310        11743  0.026399  0.022333
# 25      0          Northern_Europe    355        11743  0.030231  0.028595
# 1       0            North_America   1451        11743  0.123563  0.107990
# 28      0               Literature    442        11743  0.037639  0.036126
# 34      0                   Sports    447        11743  0.038065  0.028924
# 31      0   Business_and_economics    555        11743  0.047262  0.041035
# 24      1          Northern_Europe  13019       354989  0.036674  0.028595
# 3       1                    Music  21426       354989  0.060357  0.042855
# 48      1               Television   6572       354989  0.018513  0.015417
# 15      1                    Films  14698       354989  0.041404  0.030926
# 33      1                   Sports  11476       354989  0.032328  0.028924
# 54      1               South_Asia   6116       354989  0.017229  0.014898
# 51      1                  History   6285       354989  0.017705  0.016017
# 45      1           Food_and_drink   6588       354989  0.018558  0.015612
# 57      1          Southern_Europe   5982       354989  0.016851  0.016014
# 39      1           Western_Europe   8795       354989  0.024775  0.022333
# 14      2        Medicine_&_Health    379         7204  0.052610  0.047859
# 7       2  Philosophy_and_religion    682         7204  0.094670  0.067144
# 50      2               Television    117         7204  0.016241  0.015417
# 46      2           Food_and_drink    135         7204  0.018740  0.015612
# 43      2     Military_and_warfare    266         7204  0.036924  0.026369
# 19      2  Politics_and_government    431         7204  0.059828  0.043216
# 52      2                  History    145         7204  0.020128  0.016017
# 38      2               Technology    264         7204  0.036646  0.032364
# 11      2                Computing    459         7204  0.063715  0.056851
# 32      2   Business_and_economics    294         7204  0.040811  0.041035
#
#          std         z
# 22  0.021818  1.154543
# 37  0.004816  0.193542
# 55  0.003652  0.514259
# 58  0.001609  0.632440
# 40  0.005695  0.713986
# 25  0.009010  0.181602
# 1   0.017726  0.878518
# 28  0.001538  0.984222
# 34  0.011236  0.813528
# 31  0.006118  1.017828
# 24  0.009010  0.896754
# 3   0.016890  1.036220
# 48  0.003580  0.864834
# 15  0.009930  1.055194
# 33  0.011236  0.302905
# 54  0.003652  0.638222
# 51  0.005166  0.326717
# 45  0.005261  0.560038
# 57  0.001609  0.520448
# 39  0.005695  0.428925
# 14  0.004977  0.954546
# 7   0.024142  1.140152
# 50  0.003580  0.230189
# 46  0.005261  0.594491
# 43  0.009580  1.101766
# 19  0.015444  1.075660
# 52  0.005166  0.795777
# 38  0.004816  0.889082
# 11  0.006215  1.104431
# 32  0.006118 -0.036664

# %%
topics =order_counts2["topic_leaf"].unique()

# %%
order_counts2["topic_leaf"] = order_counts2["topic_leaf"].apply(lambda x: x.replace("_"," "))

# %%
order_counts2 = order_counts2.sort_values(by = ["order","z"],ascending=[False,False])

# %%
colors = ["#A5D8FF","#FFC53A","#B26700"]

# %%
p = pd.DataFrame([[2,"Response"], [1,"Main content"], [0,"Boilerplate"]], columns = ["order", "name_"])
order_counts2 = p.merge(order_counts2, on = "order")

# %%
order_counts2
# Out:
#     order         name_               topic_leaf    url  order_count  \
# 0       2      Response  Philosophy and religion    682         7204
# 1       2      Response                Computing    459         7204
# 2       2      Response     Military and warfare    266         7204
# 3       2      Response  Politics and government    431         7204
# 4       2      Response        Medicine & Health    379         7204
# 5       2      Response               Technology    264         7204
# 6       2      Response                  History    145         7204
# 7       2      Response           Food and drink    135         7204
# 8       2      Response               Television    117         7204
# 9       2      Response   Business and economics    294         7204
# 10      2      Response                  Biology    277         7204
# 11      2      Response                    Films    156         7204
# 12      2      Response                    Music    192         7204
# 13      2      Response               Literature    249         7204
# 14      2      Response          Northern Europe    136         7204
# 15      2      Response            North America    639         7204
# 16      2      Response                   Sports    118         7204
# 17      2      Response           Western Europe    114         7204
# 18      2      Response               South Asia     77         7204
# 19      2      Response          Southern Europe    102         7204
# 20      1  Main content                    Films  14698       354989
# 21      1  Main content                    Music  21426       354989
# 22      1  Main content          Northern Europe  13019       354989
# 23      1  Main content               Television   6572       354989
# 24      1  Main content               South Asia   6116       354989
# 25      1  Main content           Food and drink   6588       354989
# 26      1  Main content          Southern Europe   5982       354989
# 27      1  Main content           Western Europe   8795       354989
# 28      1  Main content                  History   6285       354989
# 29      1  Main content                   Sports  11476       354989
# 30      1  Main content            North America  39655       354989
# 31      1  Main content               Literature  12841       354989
# 32      1  Main content  Politics and government  14386       354989
# 33      1  Main content     Military and warfare   8505       354989
# 34      1  Main content                Computing  19607       354989
# 35      1  Main content  Philosophy and religion  20306       354989
# 36      1  Main content                  Biology  13394       354989
# 37      1  Main content   Business and economics  12436       354989
# 38      1  Main content        Medicine & Health  15152       354989
# 39      1  Main content               Technology   9638       354989
# 40      0   Boilerplate                  Biology    891        11743
# 41      0   Boilerplate   Business and economics    555        11743
# 42      0   Boilerplate               Literature    442        11743
# 43      0   Boilerplate            North America   1451        11743
# 44      0   Boilerplate                   Sports    447        11743
# 45      0   Boilerplate           Western Europe    310        11743
# 46      0   Boilerplate          Southern Europe    200        11743
# 47      0   Boilerplate               South Asia    197        11743
# 48      0   Boilerplate               Technology    391        11743
# 49      0   Boilerplate          Northern Europe    355        11743
# 50      0   Boilerplate        Medicine & Health    567        11743
# 51      0   Boilerplate                    Music    488        11743
# 52      0   Boilerplate                    Films    349        11743
# 53      0   Boilerplate  Philosophy and religion    582        11743
# 54      0   Boilerplate                Computing    606        11743
# 55      0   Boilerplate     Military and warfare    214        11743
# 56      0   Boilerplate  Politics and government    344        11743
# 57      0   Boilerplate               Television    135        11743
# 58      0   Boilerplate                  History    120        11743
# 59      0   Boilerplate           Food and drink    112        11743
#
#            p      mean       std         z
# 0   0.094670  0.067144  0.024142  1.140152
# 1   0.063715  0.056851  0.006215  1.104431
# 2   0.036924  0.026369  0.009580  1.101766
# 3   0.059828  0.043216  0.015444  1.075660
# 4   0.052610  0.047859  0.004977  0.954546
# 5   0.036646  0.032364  0.004816  0.889082
# 6   0.020128  0.016017  0.005166  0.795777
# 7   0.018740  0.015612  0.005261  0.594491
# 8   0.016241  0.015417  0.003580  0.230189
# 9   0.040811  0.041035  0.006118 -0.036664
# 10  0.038451  0.050686  0.021818 -0.560769
# 11  0.021655  0.030926  0.009930 -0.933706
# 12  0.026652  0.042855  0.016890 -0.959343
# 13  0.034564  0.036126  0.001538 -1.015065
# 14  0.018878  0.028595  0.009010 -1.078356
# 15  0.088701  0.107990  0.017726 -1.088223
# 16  0.016380  0.028924  0.011236 -1.116432
# 17  0.015825  0.022333  0.005695 -1.142912
# 18  0.010689  0.014898  0.003652 -1.152480
# 19  0.014159  0.016014  0.001609 -1.152889
# 20  0.041404  0.030926  0.009930  1.055194
# 21  0.060357  0.042855  0.016890  1.036220
# 22  0.036674  0.028595  0.009010  0.896754
# 23  0.018513  0.015417  0.003580  0.864834
# 24  0.017229  0.014898  0.003652  0.638222
# 25  0.018558  0.015612  0.005261  0.560038
# 26  0.016851  0.016014  0.001609  0.520448
# 27  0.024775  0.022333  0.005695  0.428925
# 28  0.017705  0.016017  0.005166  0.326717
# 29  0.032328  0.028924  0.011236  0.302905
# 30  0.111708  0.107990  0.017726  0.209706
# 31  0.036173  0.036126  0.001538  0.030843
# 32  0.040525  0.043216  0.015444 -0.174214
# 33  0.023958  0.026369  0.009580 -0.251578
# 34  0.055233  0.056851  0.006215 -0.260371
# 35  0.057202  0.067144  0.024142 -0.411838
# 36  0.037731  0.050686  0.021818 -0.593775
# 37  0.035032  0.041035  0.006118 -0.981164
# 38  0.042683  0.047859  0.004977 -1.039973
# 39  0.027150  0.032364  0.004816 -1.082624
# 40  0.075875  0.050686  0.021818  1.154543
# 41  0.047262  0.041035  0.006118  1.017828
# 42  0.037639  0.036126  0.001538  0.984222
# 43  0.123563  0.107990  0.017726  0.878518
# 44  0.038065  0.028924  0.011236  0.813528
# 45  0.026399  0.022333  0.005695  0.713986
# 46  0.017031  0.016014  0.001609  0.632440
# 47  0.016776  0.014898  0.003652  0.514259
# 48  0.033296  0.032364  0.004816  0.193542
# 49  0.030231  0.028595  0.009010  0.181602
# 50  0.048284  0.047859  0.004977  0.085427
# 51  0.041557  0.042855  0.016890 -0.076876
# 52  0.029720  0.030926  0.009930 -0.121488
# 53  0.049561  0.067144  0.024142 -0.728315
# 54  0.051605  0.056851  0.006215 -0.844061
# 55  0.018224  0.026369  0.009580 -0.850188
# 56  0.029294  0.043216  0.015444 -0.901446
# 57  0.011496  0.015417  0.003580 -1.095023
# 58  0.010219  0.016017  0.005166 -1.122495
# 59  0.009538  0.015612  0.005261 -1.154529

# %%
group = order_counts2.groupby("name_")

fig,ax=plt.subplots(figsize = (7,5))
for i,val in enumerate(topics):
    plt.axhline(i, 0,1,alpha = 0.4, linewidth = 0.3, color = "k")

for c, (name, g) in zip(colors,group):
    plt.scatter(g.p,g.topic_leaf,label = f"{name}", color = c)
#     plt.scatter(g.values,web_mean.index, label = "Web", color = "#C49799")

plt.tick_params(labelsize = 12)
plt.legend(frameon = True, loc = "lower right", fontsize = 13)
plt.xlabel("Probability of topic in order", fontsize = 15)
plt.ylabel("Top 20 ORES topics", fontsize = 15)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# ax.legend(bbox_to_anchor=(1, .5))
ax.legend(loc = "center right")

plt.savefig("/scratch/venia/web2wiki/visuals/where_and_what.pdf",dpi = 300, bbox_inches="tight")

# %%
wiki_scores = pd.read_csv("/scratch/venia/web2wiki/data/homepage2vec/10k_wiki.csv",names = ["domain","scores"])

# %%
orders_and_domain = df2.groupby("order")["order","domain"].sample(1000)
# Out:
# /tmp/ipykernel_857184/3735457340.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   orders_and_domain = df2.groupby("order")["order","domain"].sample(1000)

# %%
from homepage2vec.model import WebsiteClassifier
# Out:
# /home/veselovs/miniconda3/lib/python3.9/site-packages/huggingface_hub/snapshot_download.py:6: FutureWarning: snapshot_download.py has been made private and will no longer be available from version 0.11. Please use `from huggingface_hub import snapshot_download` to import the only public function in this module. Other members of the file may be changed without a deprecation notice.
#   warnings.warn(
# 2022-10-12 22:14:58.109434: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-12 22:14:58.109466: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
model = WebsiteClassifier(cpu_threads_count=20, dataloader_workers=20)

# %%
def get_scores(domain):
    try:
        website = model.fetch_website(domain)
        scores, embeddings = model.predict(website)
    except:
        scores = None
    return (domain,scores)


def process_samples(df):
    scores_list = []
    for i, value in df.iterrows():
        domain = value["domain"]
        scores_list.append(get_scores(domain))
    return scores_list

# %%
sample_wiki = process_samples(orders_and_domain)
# Out:
# /home/veselovs/miniconda3/lib/python3.9/site-packages/huggingface_hub/file_download.py:621: FutureWarning: `cached_download` is the legacy way to download files from the HF hub, please consider upgrading to `hf_hub_download`
#   warnings.warn(
# WARNING:urllib3.connection:Certificate did not match expected hostname: dermatologiacapilar.med.br. Certificate: {'subject': ((('commonName', 'c113708.sgvps.net'),),), 'issuer': ((('countryName', 'US'),), (('organizationName', "Let's Encrypt"),), (('commonName', 'R3'),)), 'version': 3, 'serialNumber': '04945E67C368A6D89DA84C2E3BC3CAEF58E9', 'notBefore': 'Aug 17 07:31:50 2022 GMT', 'notAfter': 'Nov 15 07:31:49 2022 GMT', 'subjectAltName': (('DNS', 'c113708.sgvps.net'),), 'OCSP': ('http://r3.o.lencr.org',), 'caIssuers': ('http://r3.i.lencr.org/',)}
# WARNING:urllib3.connection:Certificate did not match expected hostname: www.edgar.hk. Certificate: {'subject': ((('countryName', 'US'),), (('stateOrProvinceName', 'California'),), (('localityName', 'San Francisco'),), (('organizationName', 'Cloudflare, Inc.'),), (('commonName', '*.myshopify.com'),)), 'issuer': ((('countryName', 'US'),), (('organizationName', 'Cloudflare, Inc.'),), (('commonName', 'Cloudflare Inc ECC CA-3'),)), 'version': 3, 'serialNumber': '05C45C30A6E9C5541AA299C0C501DB66', 'notBefore': 'Aug 18 00:00:00 2022 GMT', 'notAfter': 'Aug 17 23:59:59 2023 GMT', 'subjectAltName': (('DNS', '*.myshopify.com'), ('DNS', 'myshopify.com')), 'OCSP': ('http://ocsp.digicert.com',), 'caIssuers': ('http://cacerts.digicert.com/CloudflareIncECCCA-3.crt',), 'crlDistributionPoints': ('http://crl3.digicert.com/CloudflareIncECCCA-3.crl', 'http://crl4.digicert.com/CloudflareIncECCCA-3.crl')}
# WARNING:urllib3.connection:Certificate did not match expected hostname: www.edgar.hk. Certificate: {'subject': ((('countryName', 'US'),), (('stateOrProvinceName', 'California'),), (('localityName', 'San Francisco'),), (('organizationName', 'Cloudflare, Inc.'),), (('commonName', '*.myshopify.com'),)), 'issuer': ((('countryName', 'US'),), (('organizationName', 'Cloudflare, Inc.'),), (('commonName', 'Cloudflare Inc ECC CA-3'),)), 'version': 3, 'serialNumber': '05C45C30A6E9C5541AA299C0C501DB66', 'notBefore': 'Aug 18 00:00:00 2022 GMT', 'notAfter': 'Aug 17 23:59:59 2023 GMT', 'subjectAltName': (('DNS', '*.myshopify.com'), ('DNS', 'myshopify.com')), 'OCSP': ('http://ocsp.digicert.com',), 'caIssuers': ('http://cacerts.digicert.com/CloudflareIncECCCA-3.crt',), 'crlDistributionPoints': ('http://crl3.digicert.com/CloudflareIncECCCA-3.crl', 'http://crl4.digicert.com/CloudflareIncECCCA-3.crl')}
# WARNING:urllib3.connection:Certificate did not match expected hostname: www.fliegerfaust.com. Certificate: {'subject': ((('commonName', '*.rebelmouse.com'),),), 'issuer': ((('countryName', 'BE'),), (('organizationName', 'GlobalSign nv-sa'),), (('commonName', 'GlobalSign Atlas R3 DV TLS CA 2022 Q2'),)), 'version': 3, 'serialNumber': '012DC8C7678DEE8E2B547A6B25881217', 'notBefore': 'May  6 10:51:28 2022 GMT', 'notAfter': 'Jun  7 10:51:27 2023 GMT', 'subjectAltName': (('DNS', '*.rebelmouse.com'),), 'OCSP': ('http://ocsp.globalsign.com/ca/gsatlasr3dvtlsca2022q2',), 'caIssuers': ('http://secure.globalsign.com/cacert/gsatlasr3dvtlsca2022q2.crt',), 'crlDistributionPoints': ('http://crl.globalsign.com/ca/gsatlasr3dvtlsca2022q2.crl',)}
# WARNING:urllib3.connection:Certificate did not match expected hostname: leagueaboveokc.com. Certificate: {'subject': ((('countryName', 'US'),), (('stateOrProvinceName', 'California'),), (('localityName', 'San Francisco'),), (('organizationName', 'Cloudflare, Inc.'),), (('commonName', '*.myshopify.com'),)), 'issuer': ((('countryName', 'US'),), (('organizationName', 'Cloudflare, Inc.'),), (('commonName', 'Cloudflare Inc ECC CA-3'),)), 'version': 3, 'serialNumber': '05C45C30A6E9C5541AA299C0C501DB66', 'notBefore': 'Aug 18 00:00:00 2022 GMT', 'notAfter': 'Aug 17 23:59:59 2023 GMT', 'subjectAltName': (('DNS', '*.myshopify.com'), ('DNS', 'myshopify.com')), 'OCSP': ('http://ocsp.digicert.com',), 'caIssuers': ('http://cacerts.digicert.com/CloudflareIncECCCA-3.crt',), 'crlDistributionPoints': ('http://crl3.digicert.com/CloudflareIncECCCA-3.crl', 'http://crl4.digicert.com/CloudflareIncECCCA-3.crl')}

# %%
tt = pd.DataFrame(sample_wiki, columns = ["domain", "scores"])
ttt = tt.merge(orders_and_domain, on = "domain", how = "left")

# %%
ttt=ttt.drop_duplicates(subset = ["domain","order"]).dropna()

# %%
ttt.to_csv("/scratch/venia/web2wiki/data/where_where.csv", index=False)

# %%
ttt = pd.read_csv("/scratch/venia/web2wiki/data/where_where.csv")

# %%
ttt["scores"] = ttt["scores"].apply(lambda x: eval(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 ttt["scores"] = ttt["scores"].apply(lambda x: eval(x))
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [81], in <lambda>(x)
# ----> 1 ttt["scores"] = ttt["scores"].apply(lambda x: eval(x))
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
scores = ttt["scores"].apply(pd.Series)

# %%
ttt2 = ttt.merge(p, on = "order")

# %%
scores["name"] = ttt2["name_"]
scores["domain"] = ttt2["domain"]

# %%
scores2 = scores.drop(columns="domain").groupby("name").mean()

# %%
scores2 = scores2[scores2.columns[-1::-1]]

# %%
scores2.columns = [k.replace("_", " ") for k in scores2.columns]

# %%
scores2["Sports"]
# Out:
# name
# Boilerplate     0.090338
# Main content    0.090249
# Response        0.089274
# Name: Sports, dtype: float64

# %%
fig,ax=plt.subplots()
for i,val in enumerate(scores2.columns):
    plt.axhline(i, 0,1,alpha = 0.4, linewidth = 0.3, color = "k")

for c, (name, g) in zip(colors, scores2.iterrows()):
    plt.scatter(g.values,g.index,label = f"{name}", color = c, alpha = 0.5)
#     plt.scatter(g.values,web_mean.index, label = "Web", color = "#C49799")

plt.tick_params(labelsize = 12)
plt.legend(frameon = True, loc = "lower right", fontsize = 13)
plt.xlabel("Probability", fontsize = 15)
plt.ylabel("Curlie topics", fontsize = 15)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# ax.legend(bbox_to_anchor=(1, .5))
ax.legend(loc = "center right")

plt.savefig("/scratch/venia/web2wiki/visuals/where_and_where.pdf",dpi = 300, bbox_inches="tight")
